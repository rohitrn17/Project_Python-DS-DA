# %% [markdown]
# ## Zomato_EDA

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Rohit\Ai_Adventures\Data\zomato.csv')
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %% [markdown]
# ### Data Cleaning.....

# %%
#1..Deleting Redundant Column


# Display the first few rows of the dataset
print("Original DataFrame:")


df = df.drop(['votes','reviews_list','menu_item','phone'], axis=1)

df.head()
# Out:
# Original DataFrame:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate      location            rest_type  \
# 0          Yes        Yes  4.1/5  Banashankari        Casual Dining
# 1          Yes         No  4.1/5  Banashankari        Casual Dining
# 2          Yes         No  3.8/5  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5  Banashankari          Quick Bites
# 4           No         No  3.8/5  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people) listed_in(type)  \
# 0  North Indian, Mughlai, Chinese                         800          Buffet
# 1     Chinese, North Indian, Thai                         800          Buffet
# 2          Cafe, Mexican, Italian                         800          Buffet
# 3      South Indian, North Indian                         300          Buffet
# 4        North Indian, Rajasthani                         600          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari
# 2    Banashankari
# 3    Banashankari
# 4    Banashankari

# %%
# 2..Renaming the columns.


# Display the original column names
print("Original column names:")
print(df.columns)
# Out:
# Original column names:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate',
#        'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
# Dictionary of old and new column names
columns_rename = {
    'listed_in(type)': 'listed_in_type',
    'name': 'rest_name',
    'approx_cost(for two people)': 'approx_cost_for_two_people',
    'listed_in(city)': 'listed_in_city'
}

df.rename(columns=columns_rename, inplace=True)
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                rest_name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate                    location            rest_type  \
# 0            Yes   4.1/5                Banashankari        Casual Dining
# 1             No   4.1/5                Banashankari        Casual Dining
# 2             No   3.8/5                Banashankari  Cafe, Casual Dining
# 3             No   3.7/5                Banashankari          Quick Bites
# 4             No   3.8/5                Basavanagudi        Casual Dining
# ...          ...     ...                         ...                  ...
# 51712         No  3.6 /5                  Whitefield                  Bar
# 51713         No     NaN                  Whitefield                  Bar
# 51714         No     NaN                  Whitefield                  Bar
# 51715        Yes  4.3 /5  ITPL Main Road, Whitefield                  Bar
# 51716         No  3.4 /5  ITPL Main Road, Whitefield   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                NaN
# 51713                                                NaN
# 51714                                                NaN
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                NaN
#
#                                      cuisines approx_cost_for_two_people  \
# 0              North Indian, Mughlai, Chinese                        800
# 1                 Chinese, North Indian, Thai                        800
# 2                      Cafe, Mexican, Italian                        800
# 3                  South Indian, North Indian                        300
# 4                    North Indian, Rajasthani                        600
# ...                                       ...                        ...
# 51712                             Continental                      1,500
# 51713                             Finger Food                        600
# 51714                             Finger Food                      2,000
# 51715                             Finger Food                      2,500
# 51716  Finger Food, North Indian, Continental                      1,500
#
#       listed_in_type listed_in_city
# 0             Buffet   Banashankari
# 1             Buffet   Banashankari
# 2             Buffet   Banashankari
# 3             Buffet   Banashankari
# 4             Buffet   Banashankari
# ...              ...            ...
# 51712  Pubs and bars     Whitefield
# 51713  Pubs and bars     Whitefield
# 51714  Pubs and bars     Whitefield
# 51715  Pubs and bars     Whitefield
# 51716  Pubs and bars     Whitefield
#
# [51717 rows x 13 columns]

# %%
##3..Dropping duplicates.
df.drop_duplicates(keep='first',inplace=True)
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address              rest_name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate      location            rest_type  \
# 0          Yes        Yes  4.1/5  Banashankari        Casual Dining
# 1          Yes         No  4.1/5  Banashankari        Casual Dining
# 2          Yes         No  3.8/5  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5  Banashankari          Quick Bites
# 4           No         No  3.8/5  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost_for_two_people listed_in_type  \
# 0  North Indian, Mughlai, Chinese                        800         Buffet
# 1     Chinese, North Indian, Thai                        800         Buffet
# 2          Cafe, Mexican, Italian                        800         Buffet
# 3      South Indian, North Indian                        300         Buffet
# 4        North Indian, Rajasthani                        600         Buffet
#
#   listed_in_city
# 0   Banashankari
# 1   Banashankari
# 2   Banashankari
# 3   Banashankari
# 4   Banashankari

# %%
#4..Cleaning individual columns.


df['rate'].replace('/5','',regex=True, inplace=True)
df
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_6912\230330438.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rate'].replace('/5','',regex=True, inplace=True)
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                rest_name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate                    location            rest_type  \
# 0            Yes   4.1                Banashankari        Casual Dining
# 1             No   4.1                Banashankari        Casual Dining
# 2             No   3.8                Banashankari  Cafe, Casual Dining
# 3             No   3.7                Banashankari          Quick Bites
# 4             No   3.8                Basavanagudi        Casual Dining
# ...          ...   ...                         ...                  ...
# 51712         No  3.6                   Whitefield                  Bar
# 51713         No   NaN                  Whitefield                  Bar
# 51714         No   NaN                  Whitefield                  Bar
# 51715        Yes  4.3   ITPL Main Road, Whitefield                  Bar
# 51716         No  3.4   ITPL Main Road, Whitefield   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                NaN
# 51713                                                NaN
# 51714                                                NaN
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                NaN
#
#                                      cuisines approx_cost_for_two_people  \
# 0              North Indian, Mughlai, Chinese                        800
# 1                 Chinese, North Indian, Thai                        800
# 2                      Cafe, Mexican, Italian                        800
# 3                  South Indian, North Indian                        300
# 4                    North Indian, Rajasthani                        600
# ...                                       ...                        ...
# 51712                             Continental                      1,500
# 51713                             Finger Food                        600
# 51714                             Finger Food                      2,000
# 51715                             Finger Food                      2,500
# 51716  Finger Food, North Indian, Continental                      1,500
#
#       listed_in_type listed_in_city
# 0             Buffet   Banashankari
# 1             Buffet   Banashankari
# 2             Buffet   Banashankari
# 3             Buffet   Banashankari
# 4             Buffet   Banashankari
# ...              ...            ...
# 51712  Pubs and bars     Whitefield
# 51713  Pubs and bars     Whitefield
# 51714  Pubs and bars     Whitefield
# 51715  Pubs and bars     Whitefield
# 51716  Pubs and bars     Whitefield
#
# [51717 rows x 13 columns]

# %%
#5..Remove the NaN values from the dataset

df['rate']=df['rate'].fillna('0')
df['dish_liked']=df['dish_liked'].fillna('-')
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                rest_name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate                    location            rest_type  \
# 0            Yes   4.1                Banashankari        Casual Dining
# 1             No   4.1                Banashankari        Casual Dining
# 2             No   3.8                Banashankari  Cafe, Casual Dining
# 3             No   3.7                Banashankari          Quick Bites
# 4             No   3.8                Basavanagudi        Casual Dining
# ...          ...   ...                         ...                  ...
# 51712         No  3.6                   Whitefield                  Bar
# 51713         No     0                  Whitefield                  Bar
# 51714         No     0                  Whitefield                  Bar
# 51715        Yes  4.3   ITPL Main Road, Whitefield                  Bar
# 51716         No  3.4   ITPL Main Road, Whitefield   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                  -
# 51713                                                  -
# 51714                                                  -
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                  -
#
#                                      cuisines approx_cost_for_two_people  \
# 0              North Indian, Mughlai, Chinese                        800
# 1                 Chinese, North Indian, Thai                        800
# 2                      Cafe, Mexican, Italian                        800
# 3                  South Indian, North Indian                        300
# 4                    North Indian, Rajasthani                        600
# ...                                       ...                        ...
# 51712                             Continental                      1,500
# 51713                             Finger Food                        600
# 51714                             Finger Food                      2,000
# 51715                             Finger Food                      2,500
# 51716  Finger Food, North Indian, Continental                      1,500
#
#       listed_in_type listed_in_city
# 0             Buffet   Banashankari
# 1             Buffet   Banashankari
# 2             Buffet   Banashankari
# 3             Buffet   Banashankari
# 4             Buffet   Banashankari
# ...              ...            ...
# 51712  Pubs and bars     Whitefield
# 51713  Pubs and bars     Whitefield
# 51714  Pubs and bars     Whitefield
# 51715  Pubs and bars     Whitefield
# 51716  Pubs and bars     Whitefield
#
# [51717 rows x 13 columns]

# %%
df['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 'NEW', '2.9', '3.5', '0',
#        '2.6', '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4', '2.2',
#        '2.3', '3.4 ', '-', '3.6 ', '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ',
#        '3.7 ', '3.1 ', '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ', '2.5 ',
#        '3.2 ', '2.6 ', '4.5 ', '4.3 ', '4.4 ', '4.9', '2.1', '2.0', '1.8',
#        '4.6 ', '4.9 ', '3.0 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ',
#        '2.2 ', '2.0 ', '1.8 '], dtype=object)

# %%
#6..Check for some more Transformations

df['rate']=df['rate'].replace("NEW|-",'0',regex=True)
df['rate']
# Out:
# 0         4.1
# 1         4.1
# 2         3.8
# 3         3.7
# 4         3.8
#          ...
# 51712    3.6
# 51713       0
# 51714       0
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: object

# %%
df['approx_cost_for_two_people']=df['approx_cost_for_two_people'].replace(',','',regex=True)
df['approx_cost_for_two_people']
# Out:
# 0         800
# 1         800
# 2         800
# 3         300
# 4         600
#          ...
# 51712    1500
# 51713     600
# 51714    2000
# 51715    2500
# 51716    1500
# Name: approx_cost_for_two_people, Length: 51717, dtype: object

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                rest_name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate                    location            rest_type  \
# 0            Yes   4.1                Banashankari        Casual Dining
# 1             No   4.1                Banashankari        Casual Dining
# 2             No   3.8                Banashankari  Cafe, Casual Dining
# 3             No   3.7                Banashankari          Quick Bites
# 4             No   3.8                Basavanagudi        Casual Dining
# ...          ...   ...                         ...                  ...
# 51712         No  3.6                   Whitefield                  Bar
# 51713         No     0                  Whitefield                  Bar
# 51714         No     0                  Whitefield                  Bar
# 51715        Yes  4.3   ITPL Main Road, Whitefield                  Bar
# 51716         No  3.4   ITPL Main Road, Whitefield   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                  -
# 51713                                                  -
# 51714                                                  -
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                  -
#
#                                      cuisines approx_cost_for_two_people  \
# 0              North Indian, Mughlai, Chinese                        800
# 1                 Chinese, North Indian, Thai                        800
# 2                      Cafe, Mexican, Italian                        800
# 3                  South Indian, North Indian                        300
# 4                    North Indian, Rajasthani                        600
# ...                                       ...                        ...
# 51712                             Continental                       1500
# 51713                             Finger Food                        600
# 51714                             Finger Food                       2000
# 51715                             Finger Food                       2500
# 51716  Finger Food, North Indian, Continental                       1500
#
#       listed_in_type listed_in_city
# 0             Buffet   Banashankari
# 1             Buffet   Banashankari
# 2             Buffet   Banashankari
# 3             Buffet   Banashankari
# 4             Buffet   Banashankari
# ...              ...            ...
# 51712  Pubs and bars     Whitefield
# 51713  Pubs and bars     Whitefield
# 51714  Pubs and bars     Whitefield
# 51715  Pubs and bars     Whitefield
# 51716  Pubs and bars     Whitefield
#
# [51717 rows x 13 columns]

# %%
# rate column convert in string to float data type
df['rate']=df['rate'].astype(float)
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                rest_name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate                    location            rest_type  \
# 0            Yes   4.1                Banashankari        Casual Dining
# 1             No   4.1                Banashankari        Casual Dining
# 2             No   3.8                Banashankari  Cafe, Casual Dining
# 3             No   3.7                Banashankari          Quick Bites
# 4             No   3.8                Basavanagudi        Casual Dining
# ...          ...   ...                         ...                  ...
# 51712         No   3.6                  Whitefield                  Bar
# 51713         No   0.0                  Whitefield                  Bar
# 51714         No   0.0                  Whitefield                  Bar
# 51715        Yes   4.3  ITPL Main Road, Whitefield                  Bar
# 51716         No   3.4  ITPL Main Road, Whitefield   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                  -
# 51713                                                  -
# 51714                                                  -
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                  -
#
#                                      cuisines approx_cost_for_two_people  \
# 0              North Indian, Mughlai, Chinese                        800
# 1                 Chinese, North Indian, Thai                        800
# 2                      Cafe, Mexican, Italian                        800
# 3                  South Indian, North Indian                        300
# 4                    North Indian, Rajasthani                        600
# ...                                       ...                        ...
# 51712                             Continental                       1500
# 51713                             Finger Food                        600
# 51714                             Finger Food                       2000
# 51715                             Finger Food                       2500
# 51716  Finger Food, North Indian, Continental                       1500
#
#       listed_in_type listed_in_city
# 0             Buffet   Banashankari
# 1             Buffet   Banashankari
# 2             Buffet   Banashankari
# 3             Buffet   Banashankari
# 4             Buffet   Banashankari
# ...              ...            ...
# 51712  Pubs and bars     Whitefield
# 51713  Pubs and bars     Whitefield
# 51714  Pubs and bars     Whitefield
# 51715  Pubs and bars     Whitefield
# 51716  Pubs and bars     Whitefield
#
# [51717 rows x 13 columns]

# %%
df['approx_cost_for_two_people']=df['approx_cost_for_two_people'].fillna(0).astype(int)
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                rest_name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table  rate                    location            rest_type  \
# 0            Yes   4.1                Banashankari        Casual Dining
# 1             No   4.1                Banashankari        Casual Dining
# 2             No   3.8                Banashankari  Cafe, Casual Dining
# 3             No   3.7                Banashankari          Quick Bites
# 4             No   3.8                Basavanagudi        Casual Dining
# ...          ...   ...                         ...                  ...
# 51712         No   3.6                  Whitefield                  Bar
# 51713         No   0.0                  Whitefield                  Bar
# 51714         No   0.0                  Whitefield                  Bar
# 51715        Yes   4.3  ITPL Main Road, Whitefield                  Bar
# 51716         No   3.4  ITPL Main Road, Whitefield   Bar, Casual Dining
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 51712                                                  -
# 51713                                                  -
# 51714                                                  -
# 51715                       Cocktails, Pizza, Buttermilk
# 51716                                                  -
#
#                                      cuisines  approx_cost_for_two_people  \
# 0              North Indian, Mughlai, Chinese                         800
# 1                 Chinese, North Indian, Thai                         800
# 2                      Cafe, Mexican, Italian                         800
# 3                  South Indian, North Indian                         300
# 4                    North Indian, Rajasthani                         600
# ...                                       ...                         ...
# 51712                             Continental                        1500
# 51713                             Finger Food                         600
# 51714                             Finger Food                        2000
# 51715                             Finger Food                        2500
# 51716  Finger Food, North Indian, Continental                        1500
#
#       listed_in_type listed_in_city
# 0             Buffet   Banashankari
# 1             Buffet   Banashankari
# 2             Buffet   Banashankari
# 3             Buffet   Banashankari
# 4             Buffet   Banashankari
# ...              ...            ...
# 51712  Pubs and bars     Whitefield
# 51713  Pubs and bars     Whitefield
# 51714  Pubs and bars     Whitefield
# 51715  Pubs and bars     Whitefield
# 51716  Pubs and bars     Whitefield
#
# [51717 rows x 13 columns]

# %% [markdown]
# # Data Visualization..

# %%
import matplotlib.pyplot as plt
import seaborn as sns

online_order = df['online_order'].value_counts()
print(online_order)
# Out:
# online_order
# Yes    30444
# No     21273
# Name: count, dtype: int64

# %% [markdown]
# ### 1...Restaurants delivering Online or not

# %%
#1. using matplotlib
df['online_order'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='online_order'>

# %%
#2. using seaborn

sns.countplot(x='online_order', data=df)
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %% [markdown]
# ### Restaurants allowing table booking or not

# %%
# 1. using matplot lib
df['book_table'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='book_table'>

# %%
# 2. using seaborn plot library
# Restaurants allowing table booking or not

sns.countplot(x='book_table',data=df)
# Out:
# <Axes: xlabel='book_table', ylabel='count'>

# %% [markdown]
# ### Table booking  vs Rate

# %%
# 1 . using matplot lib
df.groupby('book_table')['rate'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='book_table'>

# %%
# 2 . using seaborn lib
sns.barplot(x='book_table', y='rate', data=df)
# Out:
# <Axes: xlabel='book_table', ylabel='rate'>

# %% [markdown]
# ### Best Location

# %%
#1. using matplotlib


df['location'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='location'>

# %%
#2. Using Seaborn

# Best Location

b1=df.groupby('location')['rest_name'].count().reset_index()
b1
# Out:
#              location  rest_name
# 0                 BTM       5124
# 1        Banashankari        906
# 2           Banaswadi        664
# 3   Bannerghatta Road       1630
# 4        Basavanagudi        684
# ..                ...        ...
# 88     West Bangalore          6
# 89         Whitefield       2144
# 90      Wilson Garden        246
# 91          Yelahanka          6
# 92        Yeshwantpur        119
#
# [93 rows x 2 columns]

# %%
plt.title('Best Location Resto')
b1=df.groupby('location')[['rate']].sum().sort_values(by='rate',ascending=False).head(20)
sns.barplot(b1,y=b1.index,x='rate')
# Out:
# <Axes: title={'center': 'Best Location Resto'}, xlabel='rate', ylabel='location'>

# %% [markdown]
# ### Relation between Location and Rating

# %%
#1. Using Matplotlib
df.groupby('location')['rate'].mean().head().plot(kind='bar')
# Out:
# <Axes: xlabel='location'>

# %%
#2. Using Seaborn Relation between Location and Rating
plt.title('Relation between Location and Rating')
# plot create in lineplot view
sns.lineplot(y='location', x='rate',data=df)
# Out:
# <Axes: title={'center': 'Relation between Location and Rating'}, xlabel='rate', ylabel='location'>

# %%
#using seaborn plot create in barplot view
plt.figure(figsize=(30,5),dpi=100)
plt.xticks(rotation=90)
sns.barplot(x='location',y='rate', data=df)
# Out:
# <Axes: xlabel='location', ylabel='rate'>

# %% [markdown]
# ### Restaurant Type

# %%
#1. using matplotlib

df['rest_type'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='rest_type'>

# %%
#2. using seaborn

p1=df['rest_type'].value_counts().head(10)
sns.barplot(y=p1.index, x=p1)
# Out:
# <Axes: xlabel='count', ylabel='rest_type'>

# %% [markdown]
# ### Gaussian Rest type and Rating

# %%
#1. using matplot lib
plt.xlabel('Rest_Type')
df.groupby('rest_type')['rate'].mean().sort_values().tail(10).plot(kind='kde')
plt.ylabel('Ratings')
# Out:
# Text(0, 0.5, 'Ratings')

# %%
#2. using seaborn Gaussian Rest type and Rating
rest_rating = df.groupby('rest_type')[['rate']].mean()
sns.kdeplot(data=rest_rating)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Types of Services

# %%
#1. using matplotlib

df['listed_in_type'].value_counts().head(5).plot(kind='bar')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
#2. Using Seaborn - Types of Service
p1=df['listed_in_type'].value_counts().head()
sns.barplot(x=p1.index, y=p1)
# Out:
# <Axes: xlabel='listed_in_type', ylabel='count'>

# %% [markdown]
# ### Relation between Type and Rating

# %%
#1. using Matplotlib 
df.groupby('rest_type')['rate'].sum().sort_values().tail().plot(kind = 'bar')
# Out:
# <Axes: xlabel='rest_type'>

# %%
# Relation between Type and Rating
#2. using seaborn
plt.xticks(rotation=90)
p1=df.groupby('rest_type')['rate'].sum().sort_values().tail()
sns.barplot(x=p1.index, y=p1)
# Out:
# <Axes: xlabel='rest_type', ylabel='rate'>

# %% [markdown]
# ### Cost of Restaurant

# %%
#1. Using matplotlib 

df['approx_cost_for_two_people'].value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='approx_cost_for_two_people'>

# %%
#2. Using Seaborn Cost of Restaurant

plt.figure(figsize=(25,3),dpi=100)
plt.xticks(rotation=90)
plt.title("Cost of Restaurant")
sns.countplot(x='approx_cost_for_two_people', data=df)
# Out:
# <Axes: title={'center': 'Cost of Restaurant'}, xlabel='approx_cost_for_two_people', ylabel='count'>

# %% [markdown]
# ### No. of restaurants in a Location

# %%
#1. using matplotlib

df['location'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='location'>

# %%
#2. using seaborn 
plt.xticks(rotation=90)
p1=df['location'].value_counts().head()
sns.countplot(x =p1.index)
# Out:
# <Axes: xlabel='location', ylabel='count'>

# %% [markdown]
# ### Most famous restaurant chains in Bengaluru

# %%
#1. using matplotlib 
a =df.groupby(['rest_name','location'])['rate'].max().sort_values(ascending=False).head(16)
a.plot(kind='bar')
# Out:
# <Axes: xlabel='rest_name,location'>
# C:\Users\Rohit\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 131 (\x83) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\Rohit\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 130 (\x82) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\Rohit\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 131 (\x83) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Rohit\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 130 (\x82) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#2. using Pandas

a = df.groupby(['rest_name','location'])['rate'].max().sort_values(ascending=False).head(16)
a
# Out:
# rest_name                                                                         location
# Punjab Grill                                                                      Malleshwaram             4.9
# AB's - Absolute Barbecues                                                         BTM                      4.9
# Belgian Waffle Factory                                                            Koramangala 5th Block    4.9
#                                                                                   Brigade Road             4.9
# Milano Ice Cream                                                                  Indiranagar              4.9
# Flechazo                                                                          Whitefield               4.9
# SantÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Spa Cuisine  Indiranagar              4.9
# Punjab Grill                                                                      Whitefield               4.9
# Byg Brewski Brewing Company                                                       Sarjapur Road            4.9
# Asia Kitchen By Mainland China                                                    Koramangala 5th Block    4.9
# Brahmin's Coffee Bar                                                              Basavanagudi             4.8
# O.G. Variar & Sons                                                                Rajajinagar              4.8
# The Black Pearl                                                                   Marathahalli             4.8
# AB's - Absolute Barbecues                                                         Marathahalli             4.8
# The Globe Grub                                                                    Marathahalli             4.8
# AB's - Absolute Barbecues                                                         Whitefield               4.8
# Name: rate, dtype: float64

# %%
plt.title('Most famous restaurant chains in Bengaluru')


a.plot(kind = 'bar', y = a.index.get_level_values(1))
# Out:
# <Axes: title={'center': 'Most famous restaurant chains in Bengaluru'}, xlabel='rest_name,location'>
# C:\Users\Rohit\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 131 (\x83) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\Rohit\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 130 (\x82) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\Rohit\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 131 (\x83) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Rohit\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 130 (\x82) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
a
# Out:
# rest_name                                                                         location
# Punjab Grill                                                                      Malleshwaram             4.9
# AB's - Absolute Barbecues                                                         BTM                      4.9
# Belgian Waffle Factory                                                            Koramangala 5th Block    4.9
#                                                                                   Brigade Road             4.9
# Milano Ice Cream                                                                  Indiranagar              4.9
# Flechazo                                                                          Whitefield               4.9
# SantÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Spa Cuisine  Indiranagar              4.9
# Punjab Grill                                                                      Whitefield               4.9
# Byg Brewski Brewing Company                                                       Sarjapur Road            4.9
# Asia Kitchen By Mainland China                                                    Koramangala 5th Block    4.9
# Brahmin's Coffee Bar                                                              Basavanagudi             4.8
# O.G. Variar & Sons                                                                Rajajinagar              4.8
# The Black Pearl                                                                   Marathahalli             4.8
# AB's - Absolute Barbecues                                                         Marathahalli             4.8
# The Globe Grub                                                                    Marathahalli             4.8
# AB's - Absolute Barbecues                                                         Whitefield               4.8
# Name: rate, dtype: float64

# %%
# # using seaborn (rate and location)
# plt.xticks(rotation=90)
# sns.barplot(a, y = a.index.get_level_values(1), x = a.values)

# %%
df.groupby(['rest_name','location'])['rate'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='rest_name,location'>
